# %% [markdown]
# # 模型训练

# %%
import pandas as pd
RMC_SAMPLE_DF = pd.read_csv('sample.csv')
RMC_TARGET_COL = 'y'
RMC_SPLIT_COL = 'split'
RMC_TIME_COL = 'apply_month'
def RMC_SCORE_FN(df):
    return df['pred']
RMC_FEATURE_IMPORTANCE = pd.DataFrame({'feature': ['x1'], 'importance': [0.8]})
RMC_MODEL_PARAMS = {'learning_rate': 0.05, 'max_depth': 5}
